# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.basemap import Basemap

directory = "matrices\\pre_2021\\2020\\"
bbox = [36.55,42.12,53,55]  # [min_lat, max_lat, min_lon, max_lon]

def calculate_area(bbox):
    lat_min, lat_max = bbox[0][0], bbox[1][0]
    lon_min, lon_max = bbox[0][1], bbox[1][1]
    return (lat_max - lat_min) * (lon_max - lon_min)

def calculate_overlap_area(matrix_bbox, bbox):
    matrix_lat_min, matrix_lat_max = matrix_bbox[0][0], matrix_bbox[1][0]
    matrix_lon_min, matrix_lon_max = matrix_bbox[0][1], matrix_bbox[1][1]
    
    overlap_lat_min = max(matrix_lat_min, bbox[0])
    overlap_lat_max = min(matrix_lat_max, bbox[1])
    overlap_lon_min = max(matrix_lon_min, bbox[2])
    overlap_lon_max = min(matrix_lon_max, bbox[3])
    
    if overlap_lat_min < overlap_lat_max and overlap_lon_min < overlap_lon_max:
        return (overlap_lat_max - overlap_lat_min) * (overlap_lon_max - overlap_lon_min)
    else:
        return 0

def is_at_least_25_percent_within_bbox(matrix_bbox, bbox):
    matrix_area = calculate_area(matrix_bbox)
    overlap_area = calculate_overlap_area(matrix_bbox, bbox)
    return overlap_area / matrix_area >= 0.25

# def plot_matrix_and_bbox(matrix_bbox, bbox, filename, scene_index):
#     plt.figure()
    
#     # Set up the basemap
#     m = Basemap(projection='cyl', llcrnrlat=bbox[0]-1, urcrnrlat=bbox[1]+1, llcrnrlon=bbox[2]-1, urcrnrlon=bbox[3]+1, resolution='c')
#     m.bluemarble()
#     m.drawrivers(color='blue')
#     # Plot the matrix bounding box
#     matrix_lat = [matrix_bbox[0][0], matrix_bbox[1][0], matrix_bbox[1][0], matrix_bbox[0][0], matrix_bbox[0][0]]
#     matrix_lon = [matrix_bbox[0][1], matrix_bbox[0][1], matrix_bbox[1][1], matrix_bbox[1][1], matrix_bbox[0][1]]
#     x, y = m(matrix_lon, matrix_lat)
#     m.plot(x, y, label="Matrix", color='green')
    
#     # Plot the input bounding box
#     bbox_lat = [bbox[0], bbox[0], bbox[1], bbox[1], bbox[0]]
#     bbox_lon = [bbox[2], bbox[3], bbox[3], bbox[2], bbox[2]]
#     x, y = m(bbox_lon, bbox_lat)
#     m.plot(x, y, label="Bounding Box", color='blue')
#     m.scatter(matrix['longitude_center'],matrix['latitude_center'], c = matrix['xch4_corrected'], cmap = 'rainbow', s = 10, latlon = True)
#     plt.xlabel("Longitude")
#     plt.ylabel("Latitude")
#     #plt.legend()

#     plt.title(f"File: {filename}, Scene: {scene_index}")
#     plt.show()
scenes_of_interest = {}
for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    
    if os.path.exists(file_path):  # Check if the file exists
        data = np.load(file_path, allow_pickle=True)
        
        for i, matrix in enumerate(data):
            lat_min = np.nanmin(matrix['latitude_corners'])
            lat_max = np.nanmax(matrix['latitude_corners'])
            lon_min = np.nanmin(matrix['longitude_corners'])
            lon_max = np.nanmax(matrix['longitude_corners'])
            
            matrix_bbox = np.array([[lat_min, lon_min], [lat_max, lon_max]])
            
            if is_at_least_25_percent_within_bbox(matrix_bbox, bbox):
                if filename not in scenes_of_interest:
                    scenes_of_interest[filename] = []
                    scenes_of_interest[filename].append(i)
                # plot_matrix_and_bbox(matrix_bbox, bbox, filename, i)
                print(f"scene {i} in file {filename} has values inside the bounding box")
# Out:
# scene 83 in file s5p_l2_ch4_0017_11491_scenes.npy has values inside the bounding box
# scene 93 in file s5p_l2_ch4_0017_11491_scenes.npy has values inside the bounding box
# scene 103 in file s5p_l2_ch4_0017_11491_scenes.npy has values inside the bounding box
# scene 104 in file s5p_l2_ch4_0017_11491_scenes.npy has values inside the bounding box
# scene 111 in file s5p_l2_ch4_0017_11491_scenes.npy has values inside the bounding box
# scene 112 in file s5p_l2_ch4_0017_11491_scenes.npy has values inside the bounding box
# scene 87 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 90 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 91 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 93 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 94 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 98 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 99 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 103 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 104 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 108 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 112 in file s5p_l2_ch4_0017_11534_scenes.npy has values inside the bounding box
# scene 97 in file s5p_l2_ch4_0017_11576_scenes.npy has values inside the bounding box
# scene 101 in file s5p_l2_ch4_0017_11576_scenes.npy has values inside the bounding box
# scene 231 in file s5p_l2_ch4_0017_11591_scenes.npy has values inside the bounding box
# scene 234 in file s5p_l2_ch4_0017_11591_scenes.npy has values inside the bounding box
# scene 235 in file s5p_l2_ch4_0017_11591_scenes.npy has values inside the bounding box
# scene 236 in file s5p_l2_ch4_0017_11591_scenes.npy has values inside the bounding box
# scene 237 in file s5p_l2_ch4_0017_11591_scenes.npy has values inside the bounding box
# scene 129 in file s5p_l2_ch4_0017_11789_scenes.npy has values inside the bounding box
# scene 130 in file s5p_l2_ch4_0017_11789_scenes.npy has values inside the bounding box
# scene 134 in file s5p_l2_ch4_0017_11789_scenes.npy has values inside the bounding box
# scene 135 in file s5p_l2_ch4_0017_11789_scenes.npy has values inside the bounding box
# scene 210 in file s5p_l2_ch4_0017_11803_scenes.npy has values inside the bounding box
# scene 217 in file s5p_l2_ch4_0017_11803_scenes.npy has values inside the bounding box
# scene 124 in file s5p_l2_ch4_0017_11818_scenes.npy has values inside the bounding box
# scene 149 in file s5p_l2_ch4_0017_11832_scenes.npy has values inside the bounding box
# scene 74 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 75 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 82 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 84 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 90 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 91 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 97 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 98 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 104 in file s5p_l2_ch4_0017_11846_scenes.npy has values inside the bounding box
# scene 131 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 135 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 136 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 140 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 141 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 147 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 148 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 154 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 155 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 159 in file s5p_l2_ch4_0017_11860_scenes.npy has values inside the bounding box
# scene 158 in file s5p_l2_ch4_0017_11874_scenes.npy has values inside the bounding box
# scene 166 in file s5p_l2_ch4_0017_11874_scenes.npy has values inside the bounding box
# scene 175 in file s5p_l2_ch4_0017_11874_scenes.npy has values inside the bounding box
# scene 183 in file s5p_l2_ch4_0017_11874_scenes.npy has values inside the bounding box
# scene 0 in file s5p_l2_ch4_0017_11917_scenes.npy has values inside the bounding box
# scene 1 in file s5p_l2_ch4_0017_11917_scenes.npy has values inside the bounding box
# scene 6 in file s5p_l2_ch4_0017_11917_scenes.npy has values inside the bounding box
# scene 7 in file s5p_l2_ch4_0017_11917_scenes.npy has values inside the bounding box
# scene 152 in file s5p_l2_ch4_0017_11931_scenes.npy has values inside the bounding box
# scene 158 in file s5p_l2_ch4_0017_11931_scenes.npy has values inside the bounding box
# scene 159 in file s5p_l2_ch4_0017_11931_scenes.npy has values inside the bounding box
# scene 160 in file s5p_l2_ch4_0017_11931_scenes.npy has values inside the bounding box
# scene 161 in file s5p_l2_ch4_0017_11931_scenes.npy has values inside the bounding box
# scene 164 in file s5p_l2_ch4_0017_11931_scenes.npy has values inside the bounding box
# scene 167 in file s5p_l2_ch4_0017_11974_scenes.npy has values inside the bounding box
# scene 168 in file s5p_l2_ch4_0017_11974_scenes.npy has values inside the bounding box
# scene 169 in file s5p_l2_ch4_0017_11974_scenes.npy has values inside the bounding box
# scene 170 in file s5p_l2_ch4_0017_11974_scenes.npy has values inside the bounding box
# scene 171 in file s5p_l2_ch4_0017_11974_scenes.npy has values inside the bounding box
# scene 172 in file s5p_l2_ch4_0017_11974_scenes.npy has values inside the bounding box
# scene 145 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 147 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 148 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 150 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 151 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 152 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 153 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 155 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 156 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 160 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 165 in file s5p_l2_ch4_0017_11988_scenes.npy has values inside the bounding box
# scene 176 in file s5p_l2_ch4_0017_12002_scenes.npy has values inside the bounding box
# scene 186 in file s5p_l2_ch4_0017_12002_scenes.npy has values inside the bounding box
# scene 187 in file s5p_l2_ch4_0017_12002_scenes.npy has values inside the bounding box
# scene 195 in file s5p_l2_ch4_0017_12002_scenes.npy has values inside the bounding box
# scene 196 in file s5p_l2_ch4_0017_12002_scenes.npy has values inside the bounding box
# scene 203 in file s5p_l2_ch4_0017_12002_scenes.npy has values inside the bounding box
# scene 204 in file s5p_l2_ch4_0017_12002_scenes.npy has values inside the bounding box
# scene 196 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 206 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 216 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 217 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 226 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 227 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 236 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 237 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 247 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 256 in file s5p_l2_ch4_0017_12016_scenes.npy has values inside the bounding box
# scene 164 in file s5p_l2_ch4_0017_12045_scenes.npy has values inside the bounding box
# scene 168 in file s5p_l2_ch4_0017_12045_scenes.npy has values inside the bounding box
# scene 26 in file s5p_l2_ch4_0017_12073_scenes.npy has values inside the bounding box
# scene 20 in file s5p_l2_ch4_0017_12087_scenes.npy has values inside the bounding box
# scene 22 in file s5p_l2_ch4_0017_12087_scenes.npy has values inside the bounding box
# scene 23 in file s5p_l2_ch4_0017_12087_scenes.npy has values inside the bounding box
# scene 25 in file s5p_l2_ch4_0017_12087_scenes.npy has values inside the bounding box
# scene 26 in file s5p_l2_ch4_0017_12087_scenes.npy has values inside the bounding box
# scene 27 in file s5p_l2_ch4_0017_12087_scenes.npy has values inside the bounding box
# scene 191 in file s5p_l2_ch4_0017_12101_scenes.npy has values inside the bounding box
# scene 198 in file s5p_l2_ch4_0017_12101_scenes.npy has values inside the bounding box
# scene 87 in file s5p_l2_ch4_0017_12144_scenes.npy has values inside the bounding box
# scene 93 in file s5p_l2_ch4_0017_12144_scenes.npy has values inside the bounding box
# scene 94 in file s5p_l2_ch4_0017_12144_scenes.npy has values inside the bounding box
# scene 105 in file s5p_l2_ch4_0017_12172_scenes.npy has values inside the bounding box
# scene 115 in file s5p_l2_ch4_0017_12172_scenes.npy has values inside the bounding box
# scene 116 in file s5p_l2_ch4_0017_12172_scenes.npy has values inside the bounding box
# scene 125 in file s5p_l2_ch4_0017_12172_scenes.npy has values inside the bounding box
# scene 126 in file s5p_l2_ch4_0017_12172_scenes.npy has values inside the bounding box
# scene 135 in file s5p_l2_ch4_0017_12172_scenes.npy has values inside the bounding box
# scene 136 in file s5p_l2_ch4_0017_12172_scenes.npy has values inside the bounding box
# scene 143 in file s5p_l2_ch4_0017_12243_scenes.npy has values inside the bounding box
# scene 146 in file s5p_l2_ch4_0017_12243_scenes.npy has values inside the bounding box
# scene 150 in file s5p_l2_ch4_0017_12243_scenes.npy has values inside the bounding box
# scene 159 in file s5p_l2_ch4_0017_12243_scenes.npy has values inside the bounding box
# scene 81 in file s5p_l2_ch4_0017_12286_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_12286_scenes.npy has values inside the bounding box
# scene 65 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 66 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 69 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 70 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 71 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 75 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 81 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 82 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 88 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 89 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 97 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 105 in file s5p_l2_ch4_0017_12300_scenes.npy has values inside the bounding box
# scene 106 in file s5p_l2_ch4_0017_12343_scenes.npy has values inside the bounding box
# scene 107 in file s5p_l2_ch4_0017_12343_scenes.npy has values inside the bounding box
# scene 109 in file s5p_l2_ch4_0017_12343_scenes.npy has values inside the bounding box
# scene 47 in file s5p_l2_ch4_0017_12385_scenes.npy has values inside the bounding box
# scene 53 in file s5p_l2_ch4_0017_12385_scenes.npy has values inside the bounding box
# scene 16 in file s5p_l2_ch4_0017_12399_scenes.npy has values inside the bounding box
# scene 23 in file s5p_l2_ch4_0017_12399_scenes.npy has values inside the bounding box
# scene 31 in file s5p_l2_ch4_0017_12399_scenes.npy has values inside the bounding box
# scene 39 in file s5p_l2_ch4_0017_12399_scenes.npy has values inside the bounding box
# scene 40 in file s5p_l2_ch4_0017_12399_scenes.npy has values inside the bounding box
# scene 48 in file s5p_l2_ch4_0017_12399_scenes.npy has values inside the bounding box
# scene 49 in file s5p_l2_ch4_0017_12399_scenes.npy has values inside the bounding box
# scene 57 in file s5p_l2_ch4_0017_12399_scenes.npy has values inside the bounding box
# scene 58 in file s5p_l2_ch4_0017_12399_scenes.npy has values inside the bounding box
# scene 35 in file s5p_l2_ch4_0017_12456_scenes.npy has values inside the bounding box
# scene 16 in file s5p_l2_ch4_0017_12513_scenes.npy has values inside the bounding box
# scene 18 in file s5p_l2_ch4_0017_12513_scenes.npy has values inside the bounding box
# scene 92 in file s5p_l2_ch4_0017_12555_scenes.npy has values inside the bounding box
# scene 95 in file s5p_l2_ch4_0017_12555_scenes.npy has values inside the bounding box
# scene 105 in file s5p_l2_ch4_0017_12555_scenes.npy has values inside the bounding box
# scene 111 in file s5p_l2_ch4_0017_12555_scenes.npy has values inside the bounding box
# scene 117 in file s5p_l2_ch4_0017_12555_scenes.npy has values inside the bounding box
# scene 31 in file s5p_l2_ch4_0017_12584_scenes.npy has values inside the bounding box
# scene 5 in file s5p_l2_ch4_0017_12754_scenes.npy has values inside the bounding box
# scene 6 in file s5p_l2_ch4_0017_12754_scenes.npy has values inside the bounding box
# scene 7 in file s5p_l2_ch4_0017_12754_scenes.npy has values inside the bounding box
# scene 153 in file s5p_l2_ch4_0017_12782_scenes.npy has values inside the bounding box
# scene 156 in file s5p_l2_ch4_0017_12782_scenes.npy has values inside the bounding box
# scene 159 in file s5p_l2_ch4_0017_12782_scenes.npy has values inside the bounding box
# scene 27 in file s5p_l2_ch4_0017_12825_scenes.npy has values inside the bounding box
# scene 30 in file s5p_l2_ch4_0017_12825_scenes.npy has values inside the bounding box
# scene 33 in file s5p_l2_ch4_0017_12825_scenes.npy has values inside the bounding box
# scene 35 in file s5p_l2_ch4_0017_12825_scenes.npy has values inside the bounding box
# scene 120 in file s5p_l2_ch4_0017_12938_scenes.npy has values inside the bounding box
# scene 47 in file s5p_l2_ch4_0017_12967_scenes.npy has values inside the bounding box
# scene 52 in file s5p_l2_ch4_0017_12967_scenes.npy has values inside the bounding box
# scene 58 in file s5p_l2_ch4_0017_12967_scenes.npy has values inside the bounding box
# scene 65 in file s5p_l2_ch4_0017_12967_scenes.npy has values inside the bounding box
# scene 16 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 17 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 21 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 22 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 28 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 29 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 35 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 36 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 44 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 51 in file s5p_l2_ch4_0017_12981_scenes.npy has values inside the bounding box
# scene 34 in file s5p_l2_ch4_0017_12995_scenes.npy has values inside the bounding box
# scene 35 in file s5p_l2_ch4_0017_12995_scenes.npy has values inside the bounding box
# scene 44 in file s5p_l2_ch4_0017_12995_scenes.npy has values inside the bounding box
# scene 45 in file s5p_l2_ch4_0017_12995_scenes.npy has values inside the bounding box
# scene 54 in file s5p_l2_ch4_0017_12995_scenes.npy has values inside the bounding box
# scene 63 in file s5p_l2_ch4_0017_12995_scenes.npy has values inside the bounding box
# scene 72 in file s5p_l2_ch4_0017_12995_scenes.npy has values inside the bounding box
# scene 81 in file s5p_l2_ch4_0017_12995_scenes.npy has values inside the bounding box
# scene 119 in file s5p_l2_ch4_0017_13009_scenes.npy has values inside the bounding box
# scene 128 in file s5p_l2_ch4_0017_13009_scenes.npy has values inside the bounding box
# scene 136 in file s5p_l2_ch4_0017_13009_scenes.npy has values inside the bounding box
# scene 48 in file s5p_l2_ch4_0017_13038_scenes.npy has values inside the bounding box
# scene 51 in file s5p_l2_ch4_0017_13038_scenes.npy has values inside the bounding box
# scene 53 in file s5p_l2_ch4_0017_13038_scenes.npy has values inside the bounding box
# scene 55 in file s5p_l2_ch4_0017_13038_scenes.npy has values inside the bounding box
# scene 40 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 44 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 45 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 50 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 55 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 60 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 61 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 68 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 69 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 73 in file s5p_l2_ch4_0017_13052_scenes.npy has values inside the bounding box
# scene 38 in file s5p_l2_ch4_0017_13222_scenes.npy has values inside the bounding box
# scene 39 in file s5p_l2_ch4_0017_13222_scenes.npy has values inside the bounding box
# scene 41 in file s5p_l2_ch4_0017_13222_scenes.npy has values inside the bounding box
# scene 28 in file s5p_l2_ch4_0017_13378_scenes.npy has values inside the bounding box
# scene 29 in file s5p_l2_ch4_0017_13378_scenes.npy has values inside the bounding box
# scene 59 in file s5p_l2_ch4_0017_13421_scenes.npy has values inside the bounding box
# scene 67 in file s5p_l2_ch4_0017_13421_scenes.npy has values inside the bounding box
# scene 68 in file s5p_l2_ch4_0017_13421_scenes.npy has values inside the bounding box
# scene 74 in file s5p_l2_ch4_0017_13421_scenes.npy has values inside the bounding box
# scene 78 in file s5p_l2_ch4_0017_13421_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_13421_scenes.npy has values inside the bounding box
# scene 84 in file s5p_l2_ch4_0017_13421_scenes.npy has values inside the bounding box
# scene 89 in file s5p_l2_ch4_0017_13421_scenes.npy has values inside the bounding box
# scene 93 in file s5p_l2_ch4_0017_13421_scenes.npy has values inside the bounding box
# scene 85 in file s5p_l2_ch4_0017_13449_scenes.npy has values inside the bounding box
# scene 90 in file s5p_l2_ch4_0017_13449_scenes.npy has values inside the bounding box
# scene 98 in file s5p_l2_ch4_0017_13449_scenes.npy has values inside the bounding box
# scene 110 in file s5p_l2_ch4_0017_13463_scenes.npy has values inside the bounding box
# scene 113 in file s5p_l2_ch4_0017_13463_scenes.npy has values inside the bounding box
# scene 65 in file s5p_l2_ch4_0017_13492_scenes.npy has values inside the bounding box
# scene 71 in file s5p_l2_ch4_0017_13492_scenes.npy has values inside the bounding box
# scene 77 in file s5p_l2_ch4_0017_13492_scenes.npy has values inside the bounding box
# scene 62 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 69 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 70 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 77 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 82 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 88 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 89 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 94 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 99 in file s5p_l2_ch4_0017_13506_scenes.npy has values inside the bounding box
# scene 97 in file s5p_l2_ch4_0017_13520_scenes.npy has values inside the bounding box
# scene 106 in file s5p_l2_ch4_0017_13520_scenes.npy has values inside the bounding box
# scene 107 in file s5p_l2_ch4_0017_13520_scenes.npy has values inside the bounding box
# scene 115 in file s5p_l2_ch4_0017_13520_scenes.npy has values inside the bounding box
# scene 116 in file s5p_l2_ch4_0017_13520_scenes.npy has values inside the bounding box
# scene 124 in file s5p_l2_ch4_0017_13520_scenes.npy has values inside the bounding box
# scene 132 in file s5p_l2_ch4_0017_13520_scenes.npy has values inside the bounding box
# scene 140 in file s5p_l2_ch4_0017_13520_scenes.npy has values inside the bounding box
# scene 162 in file s5p_l2_ch4_0017_13534_scenes.npy has values inside the bounding box
# scene 172 in file s5p_l2_ch4_0017_13534_scenes.npy has values inside the bounding box
# scene 173 in file s5p_l2_ch4_0017_13534_scenes.npy has values inside the bounding box
# scene 183 in file s5p_l2_ch4_0017_13534_scenes.npy has values inside the bounding box
# scene 184 in file s5p_l2_ch4_0017_13534_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_13563_scenes.npy has values inside the bounding box
# scene 89 in file s5p_l2_ch4_0017_13563_scenes.npy has values inside the bounding box
# scene 96 in file s5p_l2_ch4_0017_13563_scenes.npy has values inside the bounding box
# scene 102 in file s5p_l2_ch4_0017_13563_scenes.npy has values inside the bounding box
# scene 61 in file s5p_l2_ch4_0017_13591_scenes.npy has values inside the bounding box
# scene 69 in file s5p_l2_ch4_0017_13591_scenes.npy has values inside the bounding box
# scene 77 in file s5p_l2_ch4_0017_13591_scenes.npy has values inside the bounding box
# scene 59 in file s5p_l2_ch4_0017_13605_scenes.npy has values inside the bounding box
# scene 69 in file s5p_l2_ch4_0017_13605_scenes.npy has values inside the bounding box
# scene 97 in file s5p_l2_ch4_0017_13634_scenes.npy has values inside the bounding box
# scene 51 in file s5p_l2_ch4_0017_13648_scenes.npy has values inside the bounding box
# scene 55 in file s5p_l2_ch4_0017_13648_scenes.npy has values inside the bounding box
# scene 60 in file s5p_l2_ch4_0017_13648_scenes.npy has values inside the bounding box
# scene 66 in file s5p_l2_ch4_0017_13648_scenes.npy has values inside the bounding box
# scene 72 in file s5p_l2_ch4_0017_13648_scenes.npy has values inside the bounding box
# scene 78 in file s5p_l2_ch4_0017_13648_scenes.npy has values inside the bounding box
# scene 51 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 58 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 59 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 65 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 66 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 72 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 73 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 79 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 80 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 86 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 87 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 93 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 94 in file s5p_l2_ch4_0017_13662_scenes.npy has values inside the bounding box
# scene 20 in file s5p_l2_ch4_0017_13719_scenes.npy has values inside the bounding box
# scene 23 in file s5p_l2_ch4_0017_13719_scenes.npy has values inside the bounding box
# scene 27 in file s5p_l2_ch4_0017_13719_scenes.npy has values inside the bounding box
# scene 37 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 45 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 53 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 54 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 61 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 68 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 69 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 84 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 85 in file s5p_l2_ch4_0017_13747_scenes.npy has values inside the bounding box
# scene 58 in file s5p_l2_ch4_0017_13761_scenes.npy has values inside the bounding box
# scene 67 in file s5p_l2_ch4_0017_13761_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_13761_scenes.npy has values inside the bounding box
# scene 84 in file s5p_l2_ch4_0017_13761_scenes.npy has values inside the bounding box
# scene 92 in file s5p_l2_ch4_0017_13761_scenes.npy has values inside the bounding box
# scene 93 in file s5p_l2_ch4_0017_13761_scenes.npy has values inside the bounding box
# scene 100 in file s5p_l2_ch4_0017_13761_scenes.npy has values inside the bounding box
# scene 101 in file s5p_l2_ch4_0017_13761_scenes.npy has values inside the bounding box
# scene 85 in file s5p_l2_ch4_0017_13818_scenes.npy has values inside the bounding box
# scene 92 in file s5p_l2_ch4_0017_13818_scenes.npy has values inside the bounding box
# scene 99 in file s5p_l2_ch4_0017_13818_scenes.npy has values inside the bounding box
# scene 63 in file s5p_l2_ch4_0017_13832_scenes.npy has values inside the bounding box
# scene 68 in file s5p_l2_ch4_0017_13832_scenes.npy has values inside the bounding box
# scene 74 in file s5p_l2_ch4_0017_13832_scenes.npy has values inside the bounding box
# scene 82 in file s5p_l2_ch4_0017_13832_scenes.npy has values inside the bounding box
# scene 89 in file s5p_l2_ch4_0017_13832_scenes.npy has values inside the bounding box
# scene 65 in file s5p_l2_ch4_0017_13846_scenes.npy has values inside the bounding box
# scene 32 in file s5p_l2_ch4_0017_13875_scenes.npy has values inside the bounding box
# scene 33 in file s5p_l2_ch4_0017_13875_scenes.npy has values inside the bounding box
# scene 37 in file s5p_l2_ch4_0017_13875_scenes.npy has values inside the bounding box
# scene 42 in file s5p_l2_ch4_0017_13875_scenes.npy has values inside the bounding box
# scene 46 in file s5p_l2_ch4_0017_13875_scenes.npy has values inside the bounding box
# scene 50 in file s5p_l2_ch4_0017_13875_scenes.npy has values inside the bounding box
# scene 51 in file s5p_l2_ch4_0017_13875_scenes.npy has values inside the bounding box
# scene 55 in file s5p_l2_ch4_0017_13875_scenes.npy has values inside the bounding box
# scene 58 in file s5p_l2_ch4_0017_13875_scenes.npy has values inside the bounding box
# scene 58 in file s5p_l2_ch4_0017_13889_scenes.npy has values inside the bounding box
# scene 64 in file s5p_l2_ch4_0017_13889_scenes.npy has values inside the bounding box
# scene 70 in file s5p_l2_ch4_0017_13889_scenes.npy has values inside the bounding box
# scene 46 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 54 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 55 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 61 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 67 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 68 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 75 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 90 in file s5p_l2_ch4_0017_13960_scenes.npy has values inside the bounding box
# scene 39 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 48 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 57 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 58 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 66 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 67 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 75 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 84 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 93 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 94 in file s5p_l2_ch4_0017_13974_scenes.npy has values inside the bounding box
# scene 94 in file s5p_l2_ch4_0017_13988_scenes.npy has values inside the bounding box
# scene 77 in file s5p_l2_ch4_0017_14017_scenes.npy has values inside the bounding box
# scene 80 in file s5p_l2_ch4_0017_14017_scenes.npy has values inside the bounding box
# scene 82 in file s5p_l2_ch4_0017_14017_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_14017_scenes.npy has values inside the bounding box
# scene 28 in file s5p_l2_ch4_0017_14059_scenes.npy has values inside the bounding box
# scene 33 in file s5p_l2_ch4_0017_14059_scenes.npy has values inside the bounding box
# scene 40 in file s5p_l2_ch4_0017_14059_scenes.npy has values inside the bounding box
# scene 48 in file s5p_l2_ch4_0017_14059_scenes.npy has values inside the bounding box
# scene 38 in file s5p_l2_ch4_0017_14102_scenes.npy has values inside the bounding box
# scene 41 in file s5p_l2_ch4_0017_14102_scenes.npy has values inside the bounding box
# scene 44 in file s5p_l2_ch4_0017_14102_scenes.npy has values inside the bounding box
# scene 49 in file s5p_l2_ch4_0017_14102_scenes.npy has values inside the bounding box
# scene 50 in file s5p_l2_ch4_0017_14102_scenes.npy has values inside the bounding box
# scene 54 in file s5p_l2_ch4_0017_14102_scenes.npy has values inside the bounding box
# scene 61 in file s5p_l2_ch4_0017_14102_scenes.npy has values inside the bounding box
# scene 62 in file s5p_l2_ch4_0017_14130_scenes.npy has values inside the bounding box
# scene 72 in file s5p_l2_ch4_0017_14130_scenes.npy has values inside the bounding box
# scene 73 in file s5p_l2_ch4_0017_14130_scenes.npy has values inside the bounding box
# scene 82 in file s5p_l2_ch4_0017_14130_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_14130_scenes.npy has values inside the bounding box
# scene 92 in file s5p_l2_ch4_0017_14130_scenes.npy has values inside the bounding box
# scene 66 in file s5p_l2_ch4_0017_14144_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_14144_scenes.npy has values inside the bounding box
# scene 86 in file s5p_l2_ch4_0017_14144_scenes.npy has values inside the bounding box
# scene 24 in file s5p_l2_ch4_0017_14173_scenes.npy has values inside the bounding box
# scene 27 in file s5p_l2_ch4_0017_14173_scenes.npy has values inside the bounding box
# scene 28 in file s5p_l2_ch4_0017_14173_scenes.npy has values inside the bounding box
# scene 30 in file s5p_l2_ch4_0017_14173_scenes.npy has values inside the bounding box
# scene 32 in file s5p_l2_ch4_0017_14173_scenes.npy has values inside the bounding box
# scene 34 in file s5p_l2_ch4_0017_14173_scenes.npy has values inside the bounding box
# scene 44 in file s5p_l2_ch4_0017_14187_scenes.npy has values inside the bounding box
# scene 50 in file s5p_l2_ch4_0017_14187_scenes.npy has values inside the bounding box
# scene 51 in file s5p_l2_ch4_0017_14187_scenes.npy has values inside the bounding box
# scene 53 in file s5p_l2_ch4_0017_14187_scenes.npy has values inside the bounding box
# scene 54 in file s5p_l2_ch4_0017_14187_scenes.npy has values inside the bounding box
# scene 56 in file s5p_l2_ch4_0017_14187_scenes.npy has values inside the bounding box
# scene 41 in file s5p_l2_ch4_0017_14258_scenes.npy has values inside the bounding box
# scene 56 in file s5p_l2_ch4_0017_14286_scenes.npy has values inside the bounding box
# scene 52 in file s5p_l2_ch4_0017_14300_scenes.npy has values inside the bounding box
# scene 48 in file s5p_l2_ch4_0017_14329_scenes.npy has values inside the bounding box
# scene 53 in file s5p_l2_ch4_0017_14329_scenes.npy has values inside the bounding box
# scene 58 in file s5p_l2_ch4_0017_14329_scenes.npy has values inside the bounding box
# scene 63 in file s5p_l2_ch4_0017_14329_scenes.npy has values inside the bounding box
# scene 64 in file s5p_l2_ch4_0017_14329_scenes.npy has values inside the bounding box
# scene 70 in file s5p_l2_ch4_0017_14329_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_14329_scenes.npy has values inside the bounding box
# scene 77 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 82 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 88 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 89 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 93 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 94 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 99 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 100 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 106 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 107 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 113 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 114 in file s5p_l2_ch4_0017_14343_scenes.npy has values inside the bounding box
# scene 87 in file s5p_l2_ch4_0017_14357_scenes.npy has values inside the bounding box
# scene 95 in file s5p_l2_ch4_0017_14357_scenes.npy has values inside the bounding box
# scene 96 in file s5p_l2_ch4_0017_14357_scenes.npy has values inside the bounding box
# scene 102 in file s5p_l2_ch4_0017_14357_scenes.npy has values inside the bounding box
# scene 103 in file s5p_l2_ch4_0017_14357_scenes.npy has values inside the bounding box
# scene 111 in file s5p_l2_ch4_0017_14357_scenes.npy has values inside the bounding box
# scene 112 in file s5p_l2_ch4_0017_14357_scenes.npy has values inside the bounding box
# scene 121 in file s5p_l2_ch4_0017_14357_scenes.npy has values inside the bounding box
# scene 130 in file s5p_l2_ch4_0017_14357_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_14371_scenes.npy has values inside the bounding box
# scene 92 in file s5p_l2_ch4_0017_14371_scenes.npy has values inside the bounding box
# scene 89 in file s5p_l2_ch4_0017_14428_scenes.npy has values inside the bounding box
# scene 94 in file s5p_l2_ch4_0017_14428_scenes.npy has values inside the bounding box
# scene 36 in file s5p_l2_ch4_0017_14471_scenes.npy has values inside the bounding box
# scene 38 in file s5p_l2_ch4_0017_14471_scenes.npy has values inside the bounding box
# scene 43 in file s5p_l2_ch4_0017_14485_scenes.npy has values inside the bounding box
# scene 45 in file s5p_l2_ch4_0017_14485_scenes.npy has values inside the bounding box
# scene 64 in file s5p_l2_ch4_0017_14499_scenes.npy has values inside the bounding box
# scene 65 in file s5p_l2_ch4_0017_14499_scenes.npy has values inside the bounding box
# scene 69 in file s5p_l2_ch4_0017_14499_scenes.npy has values inside the bounding box
# scene 70 in file s5p_l2_ch4_0017_14499_scenes.npy has values inside the bounding box
# scene 75 in file s5p_l2_ch4_0017_14499_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_14499_scenes.npy has values inside the bounding box
# scene 55 in file s5p_l2_ch4_0017_14513_scenes.npy has values inside the bounding box
# scene 56 in file s5p_l2_ch4_0017_14513_scenes.npy has values inside the bounding box
# scene 64 in file s5p_l2_ch4_0017_14513_scenes.npy has values inside the bounding box
# scene 65 in file s5p_l2_ch4_0017_14513_scenes.npy has values inside the bounding box
# scene 72 in file s5p_l2_ch4_0017_14513_scenes.npy has values inside the bounding box
# scene 79 in file s5p_l2_ch4_0017_14513_scenes.npy has values inside the bounding box
# scene 85 in file s5p_l2_ch4_0017_14513_scenes.npy has values inside the bounding box
# scene 91 in file s5p_l2_ch4_0017_14513_scenes.npy has values inside the bounding box
# scene 71 in file s5p_l2_ch4_0017_14556_scenes.npy has values inside the bounding box
# scene 75 in file s5p_l2_ch4_0017_14556_scenes.npy has values inside the bounding box
# scene 87 in file s5p_l2_ch4_0017_14570_scenes.npy has values inside the bounding box
# scene 35 in file s5p_l2_ch4_0017_14598_scenes.npy has values inside the bounding box
# scene 41 in file s5p_l2_ch4_0017_14598_scenes.npy has values inside the bounding box
# scene 46 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 54 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 55 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 61 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 62 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 68 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 69 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 76 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 77 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 83 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 89 in file s5p_l2_ch4_0017_14627_scenes.npy has values inside the bounding box
# scene 35 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 42 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 43 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 49 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 50 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 55 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 56 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 61 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 62 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 69 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 70 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 77 in file s5p_l2_ch4_0017_14641_scenes.npy has values inside the bounding box
# scene 88 in file s5p_l2_ch4_0017_14655_scenes.npy has values inside the bounding box
# scene 89 in file s5p_l2_ch4_0017_14655_scenes.npy has values inside the bounding box
# scene 97 in file s5p_l2_ch4_0017_14655_scenes.npy has values inside the bounding box
# scene 98 in file s5p_l2_ch4_0017_14655_scenes.npy has values inside the bounding box
# scene 106 in file s5p_l2_ch4_0017_14655_scenes.npy has values inside the bounding box
