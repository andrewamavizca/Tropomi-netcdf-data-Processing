# %%
from my_module.data_processing import MethaneDataProcessor

# %%
processor = MethaneDataProcessor('H:\\18_17\\s5p_l2_ch4_0017_00524.nc',  bbox = [39, 42, 59, 62.5]).scenes

# %%
import matplotlib.pyplot as plt
import numpy as np
directory = "C:\\Users\\Andrew\\Desktop\\py\\venv\\matrices\\pre_2021\\2020\\s5p_l2_ch4_0017_"
scenes = np.load(f"{directory}{14655}_scenes.npy", allow_pickle=True)

for i in range(70,79):
    fig, ax = plt.subplots(1, 2, figsize=(5, 2))
    print(i)
    fig.suptitle(f"{np.nanmin(scenes[i]['latitude_corners'])}, \
                   {np.nanmax(scenes[i]['latitude_corners'])}, \
                   {np.nanmin(scenes[i]['longitude_corners'])}, \
                   {np.nanmax(scenes[i]['longitude_corners'])}", fontsize=6)
    ax[0].imshow(scenes[i]['xch4_corrected'], cmap='rainbow')
    ax[1].imshow(scenes[i]['normalized_ch4']), cmap='rainbow')
    ax[0].invert_yaxis()
    
    ax[1].invert_yaxis()
    plt.show()
# Out:
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
